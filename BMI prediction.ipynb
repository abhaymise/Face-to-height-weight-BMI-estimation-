# %% [markdown]
# ## Objective :

# %% [markdown]
# Give a human image , identify height and weight and BMI of the individual.

# %% [markdown]
# ## Solution :

# %% [markdown]
# The solution has been inspired by the paper [FACE2BMI](https://arxiv.org/pdf/1703.03156.pdf). This paper shows that face can be an important estimator of your height and weight and hence the BMI. The dataset quoted in the papaer is not publicly available hence i could not use the mentioned dataset for my work. I gathered data from internet manualyy. I have used almost similar technique in which i have used the celebrity's face to estimate their height,weight and BMI.

# %% [markdown]
# ## Solution workflow
#
#  > Image ==> Face ==>  Face embedding ==> Height
#
#  > Image ==> Face ==>  Face embedding ==> Weight
#
#  > Image ==> Face ==>  Face embedding ==> BMI

# %% [markdown]
# ## Data  Collection and Augmentation

# %% [markdown]
# The dataset consists of 5-20 images of bollywood celeberities. The various images has been taken under different conditions so that we have enough variations.
# The images that has been taken is downloaded using google serach engine results. Care has been taken care that all the images are latest. The label for each celeberity has been noted from the publicly available forums.

# %%
label_file = "./BMI data - Sheet1.csv"

# %%
import pandas as pd

# %%
image_df = pd.DataFrame(id_path,columns=['UID','path'])

# %%
profile_df = pd.read_csv(label_file)

# %%
profile_df
# Out:
#     id       UID              name  height  weight        BMI
# 0    1    akshay      akshay kumar    1.78      80  25.249337
# 1    2        ja      john abraham    1.82      94  28.378215
# 2    3     varun      varun dhawan    1.68      78  27.636054
# 3    4     tiger      Tiger shroff    1.75      72  23.510204
# 4    5    salman       Salman khan    1.74      75  24.772097
# 5    6       srk     Shahrukh khan    1.73      75  25.059307
# 6    7  ayushman  ayushman khurana    1.68      72  25.510204
# 7    8     vikky     vicky kaushal    1.83      80  23.888441
# 8    9  rajkumar      rajkumar rao    1.70      72  24.913495
# 9   10     nawaz        nawazuddin    1.68      60  21.258503
# 10  11     manoj    manoj bajpayee    1.75      68  22.204082
# 11  12    anurag    Anurag kashyap    1.78      84  26.511804
# 12  13    pankaj    Pankaj Tripati    1.75      70  22.857143
# 13  14    kirron       kirron kher    1.65      68  24.977043
# 14  15     richa     richa chadhha    1.65      57  20.936639
# 15  16     kalki     kalki koechin    1.70      53  18.339100
# 16  17   radhika      Radhika apte    1.60      55  21.484375
# 17  18    anupam       anupam kher    1.68      70  24.801587
# 18  19   supriya    supriya pathak    1.63      72  27.099251
# 19  20     ratna      ratna pathak    1.63      55  20.700817
# 20  21      amir         amir khan    1.63      70  26.346494
# 21  22    arshad      arshad warsi    1.68      70  24.801587

# %% [markdown]
# ## How is BMI calculated?
# ```
# BMI = (Weight in Kg) / ((Height in Meters) ^ 2)
# ```

# %% [markdown]
# All the training images are kept in the following directory

# %%
data_folder = "height_weight"

# %%
from glob import glob
all_files = glob(data_folder+"/*")

all_jpgs = sorted([img for img in all_files if ".jpg" in img or ".jpeg" in img or "JPG" in img])

print("Total {} photos ".format(len(all_jpgs)))
# Out:
# Total 226 photos

# %%
from pathlib import Path as p

# %%
def get_index_of_digit(string):
    import re
    match = re.search("\d", p(string).stem)
    return match.start(0)

# %%
id_path = [(p(images).stem[:(get_index_of_digit(p(images).stem))],images) for  images in all_jpgs ]

# %%
data_df = image_df.merge(profile_df) ## merged the training images with their profile

# %%
data_df
# Out:
#         UID                                              path  id  \
# 0    akshay  /home/abhay/Downloads/height_weight/akshay1.jpeg   1
# 1    akshay  /home/abhay/Downloads/height_weight/akshay10.jpg   1
# 2    akshay  /home/abhay/Downloads/height_weight/akshay11.jpg   1
# 3    akshay  /home/abhay/Downloads/height_weight/akshay12.jpg   1
# 4    akshay  /home/abhay/Downloads/height_weight/akshay13.jpg   1
# 5    akshay  /home/abhay/Downloads/height_weight/akshay14.jpg   1
# 6    akshay  /home/abhay/Downloads/height_weight/akshay15.jpg   1
# 7    akshay  /home/abhay/Downloads/height_weight/akshay16.jpg   1
# 8    akshay  /home/abhay/Downloads/height_weight/akshay17.jpg   1
# 9    akshay  /home/abhay/Downloads/height_weight/akshay18.jpg   1
# 10   akshay  /home/abhay/Downloads/height_weight/akshay19.jpg   1
# 11   akshay  /home/abhay/Downloads/height_weight/akshay2.jpeg   1
# 12   akshay  /home/abhay/Downloads/height_weight/akshay20.jpg   1
# 13   akshay   /home/abhay/Downloads/height_weight/akshay3.jpg   1
# 14   akshay   /home/abhay/Downloads/height_weight/akshay4.jpg   1
# 15   akshay   /home/abhay/Downloads/height_weight/akshay5.jpg   1
# 16   akshay   /home/abhay/Downloads/height_weight/akshay6.jpg   1
# 17   akshay   /home/abhay/Downloads/height_weight/akshay7.jpg   1
# 18   akshay   /home/abhay/Downloads/height_weight/akshay8.jpg   1
# 19   akshay   /home/abhay/Downloads/height_weight/akshay9.jpg   1
# 20     amir     /home/abhay/Downloads/height_weight/amir1.jpg  21
# 21     amir    /home/abhay/Downloads/height_weight/amir10.jpg  21
# 22     amir    /home/abhay/Downloads/height_weight/amir11.jpg  21
# 23     amir    /home/abhay/Downloads/height_weight/amir12.jpg  21
# 24     amir    /home/abhay/Downloads/height_weight/amir13.jpg  21
# 25     amir   /home/abhay/Downloads/height_weight/amir14.jpeg  21
# 26     amir    /home/abhay/Downloads/height_weight/amir15.jpg  21
# 27     amir     /home/abhay/Downloads/height_weight/amir2.jpg  21
# 28     amir     /home/abhay/Downloads/height_weight/amir3.jpg  21
# 29     amir    /home/abhay/Downloads/height_weight/amir4.jpeg  21
# ..      ...                                               ...  ..
# 196   tiger    /home/abhay/Downloads/height_weight/tiger1.jpg   4
# 197   tiger    /home/abhay/Downloads/height_weight/tiger2.jpg   4
# 198   tiger    /home/abhay/Downloads/height_weight/tiger4.jpg   4
# 199   tiger    /home/abhay/Downloads/height_weight/tiger5.jpg   4
# 200   tiger    /home/abhay/Downloads/height_weight/tiger6.jpg   4
# 201   varun    /home/abhay/Downloads/height_weight/varun1.jpg   3
# 202   varun    /home/abhay/Downloads/height_weight/varun2.jpg   3
# 203   varun    /home/abhay/Downloads/height_weight/varun3.jpg   3
# 204   varun   /home/abhay/Downloads/height_weight/varun4.jpeg   3
# 205   varun   /home/abhay/Downloads/height_weight/varun6.jpeg   3
# 206   vikky    /home/abhay/Downloads/height_weight/vikky1.jpg   8
# 207   vikky   /home/abhay/Downloads/height_weight/vikky10.jpg   8
# 208   vikky   /home/abhay/Downloads/height_weight/vikky11.jpg   8
# 209   vikky   /home/abhay/Downloads/height_weight/vikky12.jpg   8
# 210   vikky   /home/abhay/Downloads/height_weight/vikky13.jpg   8
# 211   vikky   /home/abhay/Downloads/height_weight/vikky14.jpg   8
# 212   vikky   /home/abhay/Downloads/height_weight/vikky15.jpg   8
# 213   vikky   /home/abhay/Downloads/height_weight/vikky16.jpg   8
# 214   vikky   /home/abhay/Downloads/height_weight/vikky17.jpg   8
# 215   vikky   /home/abhay/Downloads/height_weight/vikky18.jpg   8
# 216   vikky   /home/abhay/Downloads/height_weight/vikky19.jpg   8
# 217   vikky    /home/abhay/Downloads/height_weight/vikky2.jpg   8
# 218   vikky   /home/abhay/Downloads/height_weight/vikky20.jpg   8
# 219   vikky    /home/abhay/Downloads/height_weight/vikky3.jpg   8
# 220   vikky    /home/abhay/Downloads/height_weight/vikky4.jpg   8
# 221   vikky    /home/abhay/Downloads/height_weight/vikky5.jpg   8
# 222   vikky    /home/abhay/Downloads/height_weight/vikky6.jpg   8
# 223   vikky    /home/abhay/Downloads/height_weight/vikky7.jpg   8
# 224   vikky    /home/abhay/Downloads/height_weight/vikky8.jpg   8
# 225   vikky    /home/abhay/Downloads/height_weight/vikky9.jpg   8
#
#               name  height  weight        BMI
# 0     akshay kumar    1.78      80  25.249337
# 1     akshay kumar    1.78      80  25.249337
# 2     akshay kumar    1.78      80  25.249337
# 3     akshay kumar    1.78      80  25.249337
# 4     akshay kumar    1.78      80  25.249337
# 5     akshay kumar    1.78      80  25.249337
# 6     akshay kumar    1.78      80  25.249337
# 7     akshay kumar    1.78      80  25.249337
# 8     akshay kumar    1.78      80  25.249337
# 9     akshay kumar    1.78      80  25.249337
# 10    akshay kumar    1.78      80  25.249337
# 11    akshay kumar    1.78      80  25.249337
# 12    akshay kumar    1.78      80  25.249337
# 13    akshay kumar    1.78      80  25.249337
# 14    akshay kumar    1.78      80  25.249337
# 15    akshay kumar    1.78      80  25.249337
# 16    akshay kumar    1.78      80  25.249337
# 17    akshay kumar    1.78      80  25.249337
# 18    akshay kumar    1.78      80  25.249337
# 19    akshay kumar    1.78      80  25.249337
# 20       amir khan    1.63      70  26.346494
# 21       amir khan    1.63      70  26.346494
# 22       amir khan    1.63      70  26.346494
# 23       amir khan    1.63      70  26.346494
# 24       amir khan    1.63      70  26.346494
# 25       amir khan    1.63      70  26.346494
# 26       amir khan    1.63      70  26.346494
# 27       amir khan    1.63      70  26.346494
# 28       amir khan    1.63      70  26.346494
# 29       amir khan    1.63      70  26.346494
# ..             ...     ...     ...        ...
# 196   Tiger shroff    1.75      72  23.510204
# 197   Tiger shroff    1.75      72  23.510204
# 198   Tiger shroff    1.75      72  23.510204
# 199   Tiger shroff    1.75      72  23.510204
# 200   Tiger shroff    1.75      72  23.510204
# 201   varun dhawan    1.68      78  27.636054
# 202   varun dhawan    1.68      78  27.636054
# 203   varun dhawan    1.68      78  27.636054
# 204   varun dhawan    1.68      78  27.636054
# 205   varun dhawan    1.68      78  27.636054
# 206  vicky kaushal    1.83      80  23.888441
# 207  vicky kaushal    1.83      80  23.888441
# 208  vicky kaushal    1.83      80  23.888441
# 209  vicky kaushal    1.83      80  23.888441
# 210  vicky kaushal    1.83      80  23.888441
# 211  vicky kaushal    1.83      80  23.888441
# 212  vicky kaushal    1.83      80  23.888441
# 213  vicky kaushal    1.83      80  23.888441
# 214  vicky kaushal    1.83      80  23.888441
# 215  vicky kaushal    1.83      80  23.888441
# 216  vicky kaushal    1.83      80  23.888441
# 217  vicky kaushal    1.83      80  23.888441
# 218  vicky kaushal    1.83      80  23.888441
# 219  vicky kaushal    1.83      80  23.888441
# 220  vicky kaushal    1.83      80  23.888441
# 221  vicky kaushal    1.83      80  23.888441
# 222  vicky kaushal    1.83      80  23.888441
# 223  vicky kaushal    1.83      80  23.888441
# 224  vicky kaushal    1.83      80  23.888441
# 225  vicky kaushal    1.83      80  23.888441
#
# [226 rows x 7 columns]

# %% [markdown]
# ## Extract face embedding using facenet pretrained architecture

# %%
import face_recognition
import numpy as np

# %%
def get_face_encoding(image_path):
    print(image_path)
    picture_of_me = face_recognition.load_image_file(image_path)
    my_face_encoding = face_recognition.face_encodings(picture_of_me)
    if not my_face_encoding:
        print("no face found !!!")
        return np.zeros(128).tolist()
    return my_face_encoding[0].tolist()

# %%
all_faces = []

# %%
for images in data_df.path:
    face_enc = get_face_encoding(images)
    all_faces.append(face_enc)
# Out:
# /home/abhay/Downloads/height_weight/akshay1.jpeg
# /home/abhay/Downloads/height_weight/akshay10.jpg
# /home/abhay/Downloads/height_weight/akshay11.jpg
# /home/abhay/Downloads/height_weight/akshay12.jpg
# /home/abhay/Downloads/height_weight/akshay13.jpg
# /home/abhay/Downloads/height_weight/akshay14.jpg
# /home/abhay/Downloads/height_weight/akshay15.jpg
# /home/abhay/Downloads/height_weight/akshay16.jpg
# /home/abhay/Downloads/height_weight/akshay17.jpg
# /home/abhay/Downloads/height_weight/akshay18.jpg
# /home/abhay/Downloads/height_weight/akshay19.jpg
# /home/abhay/Downloads/height_weight/akshay2.jpeg
# no face found !!!
# /home/abhay/Downloads/height_weight/akshay20.jpg
# /home/abhay/Downloads/height_weight/akshay3.jpg
# /home/abhay/Downloads/height_weight/akshay4.jpg
# /home/abhay/Downloads/height_weight/akshay5.jpg
# /home/abhay/Downloads/height_weight/akshay6.jpg
# /home/abhay/Downloads/height_weight/akshay7.jpg
# /home/abhay/Downloads/height_weight/akshay8.jpg
# /home/abhay/Downloads/height_weight/akshay9.jpg
# /home/abhay/Downloads/height_weight/amir1.jpg
# /home/abhay/Downloads/height_weight/amir10.jpg
# /home/abhay/Downloads/height_weight/amir11.jpg
# /home/abhay/Downloads/height_weight/amir12.jpg
# /home/abhay/Downloads/height_weight/amir13.jpg
# /home/abhay/Downloads/height_weight/amir14.jpeg
# /home/abhay/Downloads/height_weight/amir15.jpg
# /home/abhay/Downloads/height_weight/amir2.jpg
# /home/abhay/Downloads/height_weight/amir3.jpg
# /home/abhay/Downloads/height_weight/amir4.jpeg
# no face found !!!
# /home/abhay/Downloads/height_weight/amir5.jpg
# /home/abhay/Downloads/height_weight/amir7.jpeg
# /home/abhay/Downloads/height_weight/amir8.jpg
# /home/abhay/Downloads/height_weight/amir9.jpg
# /home/abhay/Downloads/height_weight/anupam2.jpg
# /home/abhay/Downloads/height_weight/anupam3.jpg
# /home/abhay/Downloads/height_weight/anupam4.jpg
# /home/abhay/Downloads/height_weight/anupam5.jpg
# /home/abhay/Downloads/height_weight/anupam6.jpg
# /home/abhay/Downloads/height_weight/anupam7.jpeg
# /home/abhay/Downloads/height_weight/anupam8.jpg
# /home/abhay/Downloads/height_weight/anurag1.jpg
# /home/abhay/Downloads/height_weight/anurag2.jpg
# /home/abhay/Downloads/height_weight/anurag3.jpg
# /home/abhay/Downloads/height_weight/anurag4.jpg
# /home/abhay/Downloads/height_weight/anurag5.jpg
# /home/abhay/Downloads/height_weight/arshad1.jpg
# /home/abhay/Downloads/height_weight/arshad10.jpg
# /home/abhay/Downloads/height_weight/arshad11.jpg
# /home/abhay/Downloads/height_weight/arshad12.jpeg
# /home/abhay/Downloads/height_weight/arshad13.jpg
# /home/abhay/Downloads/height_weight/arshad14.jpg
# /home/abhay/Downloads/height_weight/arshad15.jpg
# /home/abhay/Downloads/height_weight/arshad16.jpg
# /home/abhay/Downloads/height_weight/arshad2.jpg
# /home/abhay/Downloads/height_weight/arshad3.jpeg
# /home/abhay/Downloads/height_weight/arshad4.jpg
# /home/abhay/Downloads/height_weight/arshad5.jpg
# /home/abhay/Downloads/height_weight/arshad6.jpg
# /home/abhay/Downloads/height_weight/arshad7.jpeg
# /home/abhay/Downloads/height_weight/arshad8.jpeg
# /home/abhay/Downloads/height_weight/arshad9.jpg
# /home/abhay/Downloads/height_weight/ayushman1.jpg
# /home/abhay/Downloads/height_weight/ayushman2.jpeg
# /home/abhay/Downloads/height_weight/ayushman3.JPG
# /home/abhay/Downloads/height_weight/ayushman4.jpg
# /home/abhay/Downloads/height_weight/ayushman5.jpg
# /home/abhay/Downloads/height_weight/ja1.jpg
# /home/abhay/Downloads/height_weight/ja10.jpg
# /home/abhay/Downloads/height_weight/ja11.jpg
# /home/abhay/Downloads/height_weight/ja12.jpg
# /home/abhay/Downloads/height_weight/ja13.jpeg
# /home/abhay/Downloads/height_weight/ja14.jpg
# /home/abhay/Downloads/height_weight/ja15.jpg
# /home/abhay/Downloads/height_weight/ja2.jpg
# /home/abhay/Downloads/height_weight/ja3.jpg
# /home/abhay/Downloads/height_weight/ja4.jpg
# /home/abhay/Downloads/height_weight/ja5.jpg
# /home/abhay/Downloads/height_weight/ja6.jpg
# /home/abhay/Downloads/height_weight/ja7.jpg
# /home/abhay/Downloads/height_weight/ja8.jpg
# /home/abhay/Downloads/height_weight/ja9.jpg
# /home/abhay/Downloads/height_weight/kalki1.jpg
# /home/abhay/Downloads/height_weight/kalki10.jpg
# /home/abhay/Downloads/height_weight/kalki11.jpg
# /home/abhay/Downloads/height_weight/kalki12.jpg
# /home/abhay/Downloads/height_weight/kalki13.jpeg
# /home/abhay/Downloads/height_weight/kalki14.jpg
# /home/abhay/Downloads/height_weight/kalki15.jpg
# /home/abhay/Downloads/height_weight/kalki2.jpg
# /home/abhay/Downloads/height_weight/kalki3.jpeg
# /home/abhay/Downloads/height_weight/kalki4.jpg
# /home/abhay/Downloads/height_weight/kalki5.jpg
# /home/abhay/Downloads/height_weight/kalki6.jpg
# /home/abhay/Downloads/height_weight/kalki7.jpg
# /home/abhay/Downloads/height_weight/kalki8.jpg
# /home/abhay/Downloads/height_weight/kalki9.jpg
# /home/abhay/Downloads/height_weight/kirron1.jpg
# /home/abhay/Downloads/height_weight/kirron10.jpg
# /home/abhay/Downloads/height_weight/kirron2.jpg
# /home/abhay/Downloads/height_weight/kirron3.jpg
# /home/abhay/Downloads/height_weight/kirron4.jpg
# /home/abhay/Downloads/height_weight/kirron5.jpg
# /home/abhay/Downloads/height_weight/kirron6.jpg
# /home/abhay/Downloads/height_weight/kirron7.jpg
# /home/abhay/Downloads/height_weight/kirron8.jpg
# /home/abhay/Downloads/height_weight/kirron9.jpeg
# /home/abhay/Downloads/height_weight/manoj1.jpg
# /home/abhay/Downloads/height_weight/manoj2.jpeg
# /home/abhay/Downloads/height_weight/manoj3.jpg
# /home/abhay/Downloads/height_weight/manoj4.jpg
# /home/abhay/Downloads/height_weight/manoj5.JPG
# /home/abhay/Downloads/height_weight/nawaz1.jpg
# /home/abhay/Downloads/height_weight/nawaz2.jpg
# /home/abhay/Downloads/height_weight/nawaz3.jpg
# /home/abhay/Downloads/height_weight/nawaz4.jpg
# /home/abhay/Downloads/height_weight/pankaj1.jpg
# /home/abhay/Downloads/height_weight/pankaj2.jpg
# /home/abhay/Downloads/height_weight/pankaj3.jpg
# /home/abhay/Downloads/height_weight/pankaj5.jpg
# /home/abhay/Downloads/height_weight/pankaj6.jpg
# /home/abhay/Downloads/height_weight/radhika1.jpg
# /home/abhay/Downloads/height_weight/radhika10.jpg
# /home/abhay/Downloads/height_weight/radhika11.jpg
# /home/abhay/Downloads/height_weight/radhika12.jpg
# /home/abhay/Downloads/height_weight/radhika13.jpg
# /home/abhay/Downloads/height_weight/radhika14.jpg
# /home/abhay/Downloads/height_weight/radhika15.jpg
# /home/abhay/Downloads/height_weight/radhika2.jpeg
# /home/abhay/Downloads/height_weight/radhika3.jpg
# /home/abhay/Downloads/height_weight/radhika4.jpg
# /home/abhay/Downloads/height_weight/radhika5.jpg
# /home/abhay/Downloads/height_weight/radhika6.jpg
# /home/abhay/Downloads/height_weight/radhika7.jpg
# /home/abhay/Downloads/height_weight/radhika8.jpg
# /home/abhay/Downloads/height_weight/radhika9.jpg
# /home/abhay/Downloads/height_weight/rajkumar1.jpg
# /home/abhay/Downloads/height_weight/rajkumar2.jpg
# /home/abhay/Downloads/height_weight/rajkumar3.jpg
# /home/abhay/Downloads/height_weight/rajkumar4.jpg
# /home/abhay/Downloads/height_weight/rajkumar5.jpg
# /home/abhay/Downloads/height_weight/ratna1.jpeg
# /home/abhay/Downloads/height_weight/ratna2.jpg
# /home/abhay/Downloads/height_weight/ratna3.jpg
# /home/abhay/Downloads/height_weight/ratna4.JPG
# /home/abhay/Downloads/height_weight/ratna5.jpg
# /home/abhay/Downloads/height_weight/ratna6.jpg
# /home/abhay/Downloads/height_weight/richa2.jpg
# /home/abhay/Downloads/height_weight/richa3.JPG
# /home/abhay/Downloads/height_weight/richa4.jpg
# /home/abhay/Downloads/height_weight/richa5.jpg
# /home/abhay/Downloads/height_weight/salman1.jpg
# /home/abhay/Downloads/height_weight/salman10.jpg
# /home/abhay/Downloads/height_weight/salman11.jpg
# /home/abhay/Downloads/height_weight/salman12.jpg
# /home/abhay/Downloads/height_weight/salman13.jpg
# /home/abhay/Downloads/height_weight/salman14.jpg
# /home/abhay/Downloads/height_weight/salman15.jpg
# /home/abhay/Downloads/height_weight/salman16.jpg
# /home/abhay/Downloads/height_weight/salman17.jpg
# /home/abhay/Downloads/height_weight/salman18.jpg
# /home/abhay/Downloads/height_weight/salman19.jpg
# /home/abhay/Downloads/height_weight/salman2.jpg
# /home/abhay/Downloads/height_weight/salman20.jpg
# /home/abhay/Downloads/height_weight/salman3.jpg
# /home/abhay/Downloads/height_weight/salman4.jpg
# /home/abhay/Downloads/height_weight/salman5.jpeg
# /home/abhay/Downloads/height_weight/salman6.jpg
# /home/abhay/Downloads/height_weight/salman7.jpg
# /home/abhay/Downloads/height_weight/salman8.jpg
# /home/abhay/Downloads/height_weight/salman9.jpg
# /home/abhay/Downloads/height_weight/srk1.jpg
# /home/abhay/Downloads/height_weight/srk10.jpeg
# /home/abhay/Downloads/height_weight/srk11.jpg
# /home/abhay/Downloads/height_weight/srk12.jpg
# /home/abhay/Downloads/height_weight/srk13.jpg
# /home/abhay/Downloads/height_weight/srk14.jpg
# /home/abhay/Downloads/height_weight/srk15.jpg
# /home/abhay/Downloads/height_weight/srk16.jpg
# /home/abhay/Downloads/height_weight/srk17.jpg
# /home/abhay/Downloads/height_weight/srk18.jpg
# /home/abhay/Downloads/height_weight/srk19.jpg
# /home/abhay/Downloads/height_weight/srk2.jpg
# /home/abhay/Downloads/height_weight/srk3.jpeg
# no face found !!!
# /home/abhay/Downloads/height_weight/srk4.jpg
# /home/abhay/Downloads/height_weight/srk5.jpg
# /home/abhay/Downloads/height_weight/srk6.jpg
# /home/abhay/Downloads/height_weight/srk7.jpg
# /home/abhay/Downloads/height_weight/srk8.jpg
# /home/abhay/Downloads/height_weight/srk9.jpg
# /home/abhay/Downloads/height_weight/supriya1.jpg
# /home/abhay/Downloads/height_weight/supriya2.jpg
# /home/abhay/Downloads/height_weight/supriya3.jpg
# /home/abhay/Downloads/height_weight/supriya4.jpg
# /home/abhay/Downloads/height_weight/supriya5.jpg
# /home/abhay/Downloads/height_weight/supriya6.jpg
# /home/abhay/Downloads/height_weight/tiger1.jpg
# /home/abhay/Downloads/height_weight/tiger2.jpg
# /home/abhay/Downloads/height_weight/tiger4.jpg
# /home/abhay/Downloads/height_weight/tiger5.jpg
# /home/abhay/Downloads/height_weight/tiger6.jpg
# /home/abhay/Downloads/height_weight/varun1.jpg
# /home/abhay/Downloads/height_weight/varun2.jpg
# /home/abhay/Downloads/height_weight/varun3.jpg
# /home/abhay/Downloads/height_weight/varun4.jpeg
# /home/abhay/Downloads/height_weight/varun6.jpeg
# /home/abhay/Downloads/height_weight/vikky1.jpg
# /home/abhay/Downloads/height_weight/vikky10.jpg
# /home/abhay/Downloads/height_weight/vikky11.jpg
# /home/abhay/Downloads/height_weight/vikky12.jpg
# /home/abhay/Downloads/height_weight/vikky13.jpg
# /home/abhay/Downloads/height_weight/vikky14.jpg
# /home/abhay/Downloads/height_weight/vikky15.jpg
# /home/abhay/Downloads/height_weight/vikky16.jpg
# /home/abhay/Downloads/height_weight/vikky17.jpg
# /home/abhay/Downloads/height_weight/vikky18.jpg
# /home/abhay/Downloads/height_weight/vikky19.jpg
# /home/abhay/Downloads/height_weight/vikky2.jpg
# /home/abhay/Downloads/height_weight/vikky20.jpg
# /home/abhay/Downloads/height_weight/vikky3.jpg
# /home/abhay/Downloads/height_weight/vikky4.jpg
# /home/abhay/Downloads/height_weight/vikky5.jpg
# /home/abhay/Downloads/height_weight/vikky6.jpg
# /home/abhay/Downloads/height_weight/vikky7.jpg
# /home/abhay/Downloads/height_weight/vikky8.jpg
# /home/abhay/Downloads/height_weight/vikky9.jpg

# %%
X = np.array(all_faces) ## This is the training data matrix

# %%
y_height = data_df.height.values ## all labels
y_weight = data_df.weight.values
y_BMI = data_df.BMI.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_height_train, y_height_test, y_weight_train, y_weight_test ,y_BMI_train, y_BMI_test = train_test_split(X, y_height,y_weight,y_BMI, random_state=1)

# %% [markdown]
# ## Metric to check the goodness of fit

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    # The coefficients
    # The mean squared error
    print("Mean squared error: %.2f"      % mean_squared_error(y_true, y_pred))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % r2_score(y_true, y_pred))
    
    errors = abs(y_pred - y_true)
    mape = 100 * np.mean(errors / y_true)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))

# %% [markdown]
# ## Model selection
#
# We will compare few regression model and select the one with better test score . We will compare :
#
# Linear Regression
#
# Ridge Linear Regression
#
# Random Forest Regressor
#
# Kernel Ridge Regressiobn

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn import  linear_model
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # simple linear regression

# %% [markdown]
# ## Height

# %%
model_height = linear_model.LinearRegression()

# %%
model_height = model_height.fit(X_train,np.log(y_height_train))

report_goodness(model_height,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.39
# Model Performance
# Average Error: 0.0244 degrees.
# Accuracy = 95.49%.

# %% [markdown]
# We can see the model is only able to explain 39% of the total variance among the variables. There is a room for improvement.

# %% [markdown]
# ## Weight

# %%
model_weight = linear_model.LinearRegression()
model_weight = model_weight.fit(X_train,np.log(y_weight_train))

# %%
report_goodness(model_height,X_test,y_weight_test)
# Out:
# Mean squared error: 13.87
# Variance score: -618.25
# Model Performance
# Average Error: 3.7218 degrees.
# Accuracy = 12.53%.

# %% [markdown]
# We can see we have got a negative value of R2. This means the the distnace between the predicted and actual height is very high or in another words our model has underfitted.

# %% [markdown]
# ## BMI

# %%
model_BMI = linear_model.LinearRegression()
model_BMI = model_BMI.fit(X_train,np.log(y_BMI_train))

# %%
report_goodness(model_height,X_test,y_BMI_test)
# Out:
# Mean squared error: 6.99
# Variance score: -568.72
# Model Performance
# Average Error: 2.6423 degrees.
# Accuracy = 16.81%.

# %% [markdown]
# We have similar performance in case of BMI as well

# %% [markdown]
# ## Ridge Linear Regression

# %% [markdown]
# ## Height

# %%
model_height = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)

# %%
model_height = model_height.fit(X_train,np.log(y_height_train))

report_goodness(model_height,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.51
# Model Performance
# Average Error: 0.0209 degrees.
# Accuracy = 96.15%.

# %% [markdown]
# ## Weight

# %%
model_weight = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)

# %%
model_weight = model_weight.fit(X_train,np.log(y_weight_train))

report_goodness(model_weight,X_test,y_weight_test)
# Out:
# Mean squared error: 0.01
# Variance score: 0.64
# Model Performance
# Average Error: 0.0740 degrees.
# Accuracy = 98.26%.

# %% [markdown]
# ## BMI

# %%
model_BMI = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)

# %%
model_BMI = model_BMI.fit(X_train,np.log(y_BMI_train))

report_goodness(model_BMI,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.68
# Model Performance
# Average Error: 0.0487 degrees.
# Accuracy = 98.46%.

# %% [markdown]
# ## Random Forest Regressor

# %% [markdown]
# ## Height

# %%
model_height = RandomForestRegressor(max_depth=2, random_state=0,
                              n_estimators=100)

# %%
model_height = model_height.fit(X_train,np.log(y_height_train))

report_goodness(model_height,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.51
# Model Performance
# Average Error: 0.0200 degrees.
# Accuracy = 96.28%.

# %% [markdown]
# #### With Hyperparameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 100, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
rf = RandomForestRegressor()

# %%
rf_height_model = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_height_model.fit(X_train,np.log(y_height_train))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=   9.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=   9.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  10.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   4.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   4.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   5.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=   8.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   27.0s
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=   8.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=   9.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.2s
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   2.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   2.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   2.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  10.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=   9.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=   9.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=   9.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  10.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=   9.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   2.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   3.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   6.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   6.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   6.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=   8.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=   7.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=   8.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  10.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  10.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  11.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   2.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   2.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.8s
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   1.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   7.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   0.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   2.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   7.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   8.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  10.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  11.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  10.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  11.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.1min
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   4.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   4.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   4.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   5.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  11.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  11.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   4.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   4.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   5.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   5.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   6.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   6.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   4.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   6.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   6.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   4.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.1s
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   5.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   4.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   4.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   4.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   5.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   6.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   6.7s
# ...
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=91, total=   3.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=   9.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  10.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  10.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   3.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.3s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   4.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   4.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.6s
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   3.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   5.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   4.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   5.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   3.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   3.4s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   6.4s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   4.0s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   6.3s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  4.2min finished
# Mean squared error: 0.00
# Variance score: 0.75
# Model Performance
# Average Error: 0.0134 degrees.
# Accuracy = 97.49%.

# %%
report_goodness(rf_height_model,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.75
# Model Performance
# Average Error: 0.0134 degrees.
# Accuracy = 97.49%.

# %% [markdown]
# We see our variance score has increased

# %% [markdown]
# ## Weight

# %%
model_weight = RandomForestRegressor(max_depth=2, random_state=0,
                              n_estimators=100)

# %%
model_weight = model_weight.fit(X_train,np.log(y_weight_train))

report_goodness(model_weight,X_test,y_weight_test)
# Out:
# Mean squared error: 0.01
# Variance score: 0.66
# Model Performance
# Average Error: 0.0653 degrees.
# Accuracy = 98.45%.

# %% [markdown]
# #### With Hyperparameter tuning

# %%
rf_weight_model = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_weight_model.fit(X_train,np.log(y_weight_train))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.4s
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.3s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  11.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  11.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  14.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   5.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   6.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   6.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=   9.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   31.9s
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=  11.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   4.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   5.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=  14.0s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   4.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  10.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=   9.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   3.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  12.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  10.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  11.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  12.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   3.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   9.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=  10.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=  10.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   4.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  11.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  12.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  12.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  11.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  10.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  14.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   3.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   2.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   1.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   1.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.5s
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   9.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.0s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   9.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=  10.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  12.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  14.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  14.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  15.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.5min
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   4.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   5.3s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  12.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   6.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   5.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  14.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   5.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   6.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   6.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   6.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   7.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   7.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   6.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   6.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   8.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   9.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   6.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   5.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   5.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   5.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   3.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   8.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   8.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   9.5s
# ...
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=73, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   2.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   2.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  13.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  13.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   4.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   4.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  17.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   5.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   5.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   6.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   2.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   4.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   6.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   6.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   7.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   4.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   5.0s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   8.9s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   6.8s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   8.1s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  5.0min finished
# RandomizedSearchCV(cv=3, error_score='raise',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=100, n_jobs=-1,
#           param_distributions={'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False], 'n_estimators': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 19, 28, 37, 46, 55, 64, 73, 82, 91, 100, None]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
report_goodness(rf_weight_model,X_test,y_weight_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.84
# Model Performance
# Average Error: 0.0442 degrees.
# Accuracy = 98.95%.

# %% [markdown]
# ## BMI

# %%
model_BMI = RandomForestRegressor(max_depth=2, random_state=0,
                              n_estimators=100)

# %%
model_BMI = model_BMI.fit(X_train,np.log(y_BMI_train))

report_goodness(model_BMI,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.74
# Model Performance
# Average Error: 0.0408 degrees.
# Accuracy = 98.70%.

# %% [markdown]
# #### With Hyperparameter tuning

# %%
rf_BMI_model = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_BMI_model.fit(X_train,np.log(y_BMI_train))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.4s
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=28, total=   0.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=10, total=   2.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=28, total=   1.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  11.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  12.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=28, total=  12.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   6.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   6.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=46, total=   6.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=64, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=  10.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   30.1s
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.3s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=  11.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=5, max_features=auto, max_depth=10, total=  12.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=10, total=   4.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.3s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=10, total=   3.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=28, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   4.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   3.6s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=64, total=   3.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  13.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  13.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=46, total=  14.0s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   2.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   1.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=5, max_features=auto, max_depth=73, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   2.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  11.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  12.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=auto, max_depth=100, total=  12.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=10, max_features=sqrt, max_depth=28, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   2.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   2.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=780, min_samples_split=5, max_features=sqrt, max_depth=64, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   8.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   8.4s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=None, total=   0.5s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=73, total=   2.8s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=None, total=   9.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=19, total=   1.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  10.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  11.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=37, total=  10.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  12.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=46, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  13.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=91, total=  14.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=46, total=   1.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   2.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   2.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=sqrt, max_depth=82, total=   3.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=19, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=560, min_samples_split=5, max_features=sqrt, max_depth=19, total=   2.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   3.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=auto, max_depth=91, total=   3.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   3.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=10, total=   0.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=auto, max_depth=None, total=   3.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=55, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.1s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.5s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=2, max_features=sqrt, max_depth=82, total=   1.3s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=82, total=   0.5s
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=82, total=   0.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=450, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=sqrt, max_depth=73, total=   0.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=560, min_samples_split=2, max_features=sqrt, max_depth=64, total=   1.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   8.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   0.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   9.2s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=100, total=   1.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=82, total=   9.3s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  13.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  13.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  14.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=19, total=  14.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.4min
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   5.6s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   6.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=46, total=   6.1s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   5.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  14.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=46, total=  15.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=670, min_samples_split=5, max_features=sqrt, max_depth=None, total=   2.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   6.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=28, total=   6.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=55, total=   0.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   7.3s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   7.5s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=5, max_features=auto, max_depth=10, total=   7.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   8.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   6.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   7.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   8.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=890, min_samples_split=2, max_features=auto, max_depth=73, total=   9.1s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=10, min_samples_split=2, max_features=sqrt, max_depth=46, total=   0.0s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.2s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.4s
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=670, min_samples_split=10, max_features=sqrt, max_depth=73, total=   2.3s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=120, min_samples_split=2, max_features=sqrt, max_depth=10, total=   0.4s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=670, min_samples_split=2, max_features=auto, max_depth=91, total=   6.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   5.7s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   6.2s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=450, min_samples_split=10, max_features=auto, max_depth=73, total=   6.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   7.5s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=sqrt, max_depth=19, total=   2.4s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   8.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=780, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=560, min_samples_split=10, max_features=auto, max_depth=None, total=   8.5s
# ...
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=91, total=   4.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=auto, max_depth=91, total=   1.9s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  12.5s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.4s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  13.9s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=2, max_features=auto, max_depth=55, total=  14.1s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=450, min_samples_split=5, max_features=auto, max_depth=91, total=   3.5s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   4.9s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   5.6s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=64, total=   1.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.6s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.2s
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=37, total=   1.1s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=340, min_samples_split=10, max_features=auto, max_depth=None, total=   6.4s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=120, min_samples_split=5, max_features=sqrt, max_depth=91, total=   0.6s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.3s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   3.0s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   3.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=780, min_samples_split=2, max_features=sqrt, max_depth=73, total=   3.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=340, min_samples_split=10, max_features=sqrt, max_depth=91, total=   1.4s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.8s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.9s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=450, min_samples_split=10, max_features=sqrt, max_depth=10, total=   1.7s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.9s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=230, min_samples_split=10, max_features=sqrt, max_depth=100, total=   0.9s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.2s
# [CV] min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.7s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=1000, min_samples_split=5, max_features=sqrt, max_depth=None, total=   3.8s
# [CV] min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=True, n_estimators=340, min_samples_split=5, max_features=sqrt, max_depth=37, total=   1.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.8s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   1.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.9s
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=230, min_samples_split=2, max_features=sqrt, max_depth=28, total=   0.8s
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV] min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=4, bootstrap=True, n_estimators=230, min_samples_split=2, max_features=auto, max_depth=37, total=   2.0s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   1.7s
# [CV] min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10
# [CV]  min_samples_leaf=2, bootstrap=False, n_estimators=120, min_samples_split=10, max_features=auto, max_depth=37, total=   2.0s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.2s
# [CV] min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91
# [CV]  min_samples_leaf=4, bootstrap=False, n_estimators=10, min_samples_split=5, max_features=auto, max_depth=91, total=   0.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   3.2s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   6.9s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   7.6s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=1, bootstrap=False, n_estimators=450, min_samples_split=2, max_features=auto, max_depth=10, total=   7.8s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   4.0s
# [CV] min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=2, max_features=sqrt, max_depth=19, total=   4.0s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   6.4s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   7.9s
# [CV]  min_samples_leaf=2, bootstrap=True, n_estimators=1000, min_samples_split=10, max_features=auto, max_depth=37, total=   7.9s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  5.0min finished
# RandomizedSearchCV(cv=3, error_score='raise',
#           estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#           fit_params=None, iid=True, n_iter=100, n_jobs=-1,
#           param_distributions={'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False], 'n_estimators': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 19, 28, 37, 46, 55, 64, 73, 82, 91, 100, None]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
report_goodness(rf_BMI_model,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.87
# Model Performance
# Average Error: 0.0272 degrees.
# Accuracy = 99.13%.

# %% [markdown]
# ## Kernel Ridge

# %% [markdown]
# ## Height

# %%
model_height = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_height = model_height.fit(X_train,np.log(y_height_train))

report_goodness(model_height,X_test,y_height_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.80
# Model Performance
# Average Error: 0.0132 degrees.
# Accuracy = 97.52%.

# %% [markdown]
# ## Weight

# %%
model_weight = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_weight = model_weight.fit(X_train,np.log(y_weight_train))

report_goodness(model_weight,X_test,y_weight_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.86
# Model Performance
# Average Error: 0.0458 degrees.
# Accuracy = 98.92%.

# %% [markdown]
# ## BMI

# %%
model_BMI = KernelRidge(kernel='rbf', gamma=0.21,alpha=0.0017)

# %%
model_BMI = model_BMI.fit(X_train,np.log(y_BMI_train))

report_goodness(model_BMI,X_test,y_BMI_test)
# Out:
# Mean squared error: 0.00
# Variance score: 0.88
# Model Performance
# Average Error: 0.0311 degrees.
# Accuracy = 99.01%.

# %%
report_goodness(model_BMI,X_test,y_BMI_test)

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# We found that kernelised Ridge regression outperformed all the models in terms of the mean squared error and expalined variance

# %% [markdown]
# ## save all models

# %%
from sklearn.externals import joblib

# %% [markdown]
# # save the model to disk

# %%
height_model = 'weight_predictor.model'
weight_model = 'height_predictor.model'
bmi_model = 'bmi_predictor.model'
joblib.dump(model_height, height_model)
joblib.dump(model_weight, weight_model)
joblib.dump(model_BMI, bmi_model)

# %% [markdown]
# # load the model from disk

# %%
height_model = joblib.load(height_model)
weight_model = joblib.load(weight_model)
bmi_model = joblib.load(bmi_model)

# %% [markdown]
# ## test

# %%
def predict_height_width_BMI(test_image,height_model,weight_model,bmi_model):
    test_array = np.expand_dims(np.array(get_face_encoding(test_image)),axis=0)
    height = np.asscalar(np.exp(height_model.predict(test_array)))
    weight = np.asscalar(np.exp(weight_model.predict(test_array)))
    bmi = np.asscalar(np.exp(bmi_model.predict(test_array)))
    return {'height':height,'weight':weight,'bmi':bmi}

# %% [markdown]
# ## prediction on test images

# %%
from IPython.display import Image

# %%
test_image = 'height_weight_test/vikky1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/vikky1.jpg
# {'bmi': 23.74157787981355,
#  'height': 1.8241874010074786,
#  'weight': 78.9550177851072}

# %%
test_image = 'height_weight_test/aamir1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/aamir1.jpg
# {'bmi': 26.85393691907381,
#  'height': 1.6537218414452746,
#  'weight': 73.44919331770976}

# %%
test_image = 'height_weight_test/akshay1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/akshay1.jpg
# {'bmi': 24.877827583519565,
#  'height': 1.7759562913263922,
#  'weight': 78.48532448422687}

# %%
test_image = 'height_weight_test/ratna1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/ratna1.jpg
# {'bmi': 20.75296458434203,
#  'height': 1.6430953754050468,
#  'weight': 56.22791284564108}

# %% [markdown]
# ## Prediction on some celebrities which is not in training set

# %%
test_image= 'height_weight_test/jaya1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/jaya3.jpg
# {'bmi': 24.578459589639998,
#  'height': 1.6470415366818987,
#  'weight': 66.682196899742}

# %%
test_image= 'height_weight_test/hrithik1.jpg' 
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/jaya1.jpg
# {'bmi': 24.65166315788692,
#  'height': 1.6260804446802757,
#  'weight': 65.24245020581978}

# %%
test_image= 'height_weight_test/rampal2.jpg' 
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/rampal2.jpg
# {'bmi': 22.992710795255977,
#  'height': 1.8096634066313946,
#  'weight': 75.64910124740388}

# %%
test_image= 'height_weight_test/hema1.jpg' 
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/jaya1.jpg
# {'bmi': 24.65166315788692,
#  'height': 1.6260804446802757,
#  'weight': 65.24245020581978}

# %%
test_image= 'height_weight_test/jamwal1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/jamwal1.jpg
# {'bmi': 22.586685253837235,
#  'height': 1.7923486154087216,
#  'weight': 72.76666251284472}

# %%
test_image= 'height_weight_test/mandira1.jpg'
Image(test_image)

# %%
predict_height_width_BMI(test_image1,height_model,weight_model,bmi_model)
# Out:
# height_weight_test/jaya1.jpg
# {'bmi': 24.65166315788692,
#  'height': 1.6260804446802757,
#  'weight': 65.24245020581978}

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Face is almost able to predict BMI correctly. There are places where it is going wrong for example if you predict heigt of really tall celebrity like rampal.
# This behavior is acceptable since we have not trained the model on such tall celebrities. Other,issue that i noticed is the face to weight tagging is not that much appropriate since the faces are from diffrent times but the weight is always the latest.
# We can get even better model if we have these mappings right.
#
# Also we can improve on height prediction if we model the torso alongwith the face. However , we need to get torso to correct height labeled data for this. In the absence of such data we can rely on the face as height estimator.
